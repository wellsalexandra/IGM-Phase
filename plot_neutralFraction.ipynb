# %% [markdown]
# <a href="https://colab.research.google.com/github/wellsalexandra/IGM-Phase/blob/main/plot_neutralFraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### This code is used to create and display a plot of the
### neutral fraction across scale factors.
### Data comes from CROC simulation and is uploaded via Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
arrA = pd.read_csv("drive/MyDrive/UoM REU Project 2023/reiA.log", sep = "\s+", usecols = [0, 13], names = ["scale", "neutral"], skiprows = 10 )
arrB = pd.read_csv("drive/MyDrive/UoM REU Project 2023/reiB.log", sep = "\s+", usecols = [0, 13], names = ["scale", "neutral"], skiprows = 10 )
arrC = pd.read_csv("drive/MyDrive/UoM REU Project 2023/reiC.log", sep = "\s+", usecols = [0, 13], names = ["scale", "neutral"], skiprows = 10 )
arrF = pd.read_csv("drive/MyDrive/UoM REU Project 2023/reiF.log", sep = "\s+", usecols = [0, 13], names = ["scale", "neutral"], skiprows = 10 )

# %%
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)

fig = plt.figure()
axis = plt.axes()

plt.plot((arrF["scale"]), (arrF["neutral"]), linestyle='solid', linewidth=2.7, label = "Late Reionization", color = 'red')
plt.plot((arrB["scale"]), (arrB["neutral"]), linestyle='dashed', linewidth=2.7, label = "Intermediate Reionization 1", color= 'orange')
plt.plot((arrA["scale"]), (arrA["neutral"]), linestyle = 'dotted', linewidth=2.7, label = "Intermediate Reionization 2", color = 'blue')
plt.plot((arrC["scale"]), (arrC["neutral"]), linestyle = 'dashdot', linewidth=2.7, label = "Early Reionziation", color = 'green')

plt.xlim(0.075, 0.14)
plt.xticks(fontsize='large')
axis.xaxis.set_minor_locator(MultipleLocator(0.002))
plt.yticks(fontsize='large')
axis.yaxis.set_minor_locator(MultipleLocator(0.04))

plt.legend(fontsize='large', loc='lower left', framealpha=0.7)

plt.xlabel("Scale Factor", fontsize = 25)
plt.ylabel("Neutral Fraction", fontsize = 25)
plt.title("Scale Factor vs Neutral Fraction", fontsize=22)
# Out:
# Text(0.5, 1.0, 'Scale Factor vs Neutral Fraction')
